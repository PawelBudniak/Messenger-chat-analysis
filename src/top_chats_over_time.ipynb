# %%
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot
import plotly.express as px
import top_chats_over_time

init_notebook_mode(connected=True)

PATH = r'C:\messenger-data\29.12.2022\facebook-100002163210723\messages\inbox'
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.12.1.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
# import biggest_chats
#
# TOP_N = 15
#
# top_chats = biggest_chats.chat_sizes(PATH)#[:TOP_N]
# biggest_chats.print_chats(top_chats)
# chats_dfs = {chat.name: stats.load_from_path(chat.path) for chat in top_chats}
# grouped = {name: stats.groupby_date(chat_df) for name, chat_df in chats_dfs.items()}
# big_df = pd.DataFrame()
# for name, msg_by_month in grouped.items():
#     data = [msg_by_month.values, msg_by_month.index, [name]*len(msg_by_month)]
#     wide_df = pd.DataFrame(data, index=['messages', 'month', 'name']).T
#     big_df = pd.concat([big_df, wide_df])
#
# result = pd.pivot(big_df, index='name', columns='month', values='messages').fillna(0)
# result

# %%
#result = top_chats_over_time.chat_sizes_by_date(r'C:\messenger-data\messages\inbox', top_n=15, freq='M', filter_groups=True)
result = top_chats_over_time.chat_sizes_by_date(PATH, top_n=15, freq='M', filter_groups=True)
# Out:
# 1. Mikołaj Bieńkowski: 45225
# 2. Ada Ardito: 37043
# 3. Michał Świątek: 16853
# 4. Daniel Sypuła: 14767
# 5. Piotrek Jaworski: 13789
# 6. Bartek Królak: 12765
# 7. Aleksander Sumiński: 8648
# 8. Piotr Frątczak: 8044
# 9. Maciek Górski: 8011
# 10. Filip Perzanowski: 6895
# 11. Konrad Lechowski: 3542
# 12. Jakub Gąsior: 3482
# 13. Bartosz Świtalski: 3298
# 14. Franek Fijałkowski: 3217
# 15. Tymek Perka: 1817

# %%
cumulative = result.cumsum()
f = px.line(cumulative, x = cumulative.index, y = cumulative.columns)
f.show()
# Out:
# <div>                            <div id="4b25b516-dbb4-41ee-9b18-4609513da4c4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4b25b516-dbb4-41ee-9b18-4609513da4c4")) {                    Plotly.newPlot(                        "4b25b516-dbb4-41ee-9b18-4609513da4c4",                        [{"hovertemplate":"name=Ada Ardito<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Ada Ardito","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ada Ardito","showlegend":true,"x":["2011-06-30T00:00:00+02:00","2011-07-31T00:00:00+02:00","2011-08-31T00:00:00+02:00","2011-09-30T00:00:00+02:00","2011-10-31T00:00:00+01:00","2011-11-30T00:00:00+01:00","2011-12-31T00:00:00+01:00","2012-01-31T00:00:00+01:00","2012-02-2
# ...

# %%
wide_cum = cumulative.T
wide_cum.columns = wide_cum.columns.strftime('%Y/%m/%d')
wide_cum.to_csv('output/result.csv') # for app.flourish bar chart race (I recommend not specifing TOP_N here)
wide_cum
# Out:
# date                 2011/06/30  2011/07/31  2011/08/31  2011/09/30  \
# name
# Ada Ardito                    0           0           0           0
# Aleksander Sumiński           1           1           1          15
# Bartek Królak                 0           0           0           0
# Bartosz Świtalski             0           0           0           0
# Daniel Sypuła                 0           0           0           0
# Filip Perzanowski             0           0           0           0
# Franek Fijałkowski            0           0           0           0
# Jakub Gąsior                  0           0           0           0
# Konrad Lechowski              0           0           0           0
# Maciek Górski                 0           0           0           0
# Michał Świątek                0           0           0           0
# Mikołaj Bieńkowski            0           0           0           0
# Piotr Frątczak                0           0           0           0
# ...

# %%
f = px.line(result, x = result.index, y = result.columns)
f.show()
# Out:
# <div>                            <div id="03969af3-6c1c-48fc-a157-869d38cb1bc2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("03969af3-6c1c-48fc-a157-869d38cb1bc2")) {                    Plotly.newPlot(                        "03969af3-6c1c-48fc-a157-869d38cb1bc2",                        [{"hovertemplate":"name=Ada Ardito<br>date=%{x}<br>value=%{y}<extra></extra>","legendgroup":"Ada Ardito","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"Ada Ardito","showlegend":true,"x":["2011-06-30T00:00:00+02:00","2011-07-31T00:00:00+02:00","2011-08-31T00:00:00+02:00","2011-09-30T00:00:00+02:00","2011-10-31T00:00:00+01:00","2011-11-30T00:00:00+01:00","2011-12-31T00:00:00+01:00","2012-01-31T00:00:00+01:00","2012-02-2
# ...

# %%
import bar_chart_race as bcr
from datetime import datetime

fname = datetime.today().strftime('%Y-%m-%d')
bcr.bar_chart_race(cumulative, filename=f'output/{fname}.mp4', n_bars=15)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:286: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
#
# C:\ProgramData\Anaconda3\lib\site-packages\bar_chart_race\_make_chart.py:287: UserWarning:
#
# FixedFormatter should only be used together with FixedLocator
